# %%
import pandas as pd
import gc
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Load the data with dtype string
df = pd.read_csv('10_ecoli_genome_data.csv', dtype=str)

# %%
#Drop columns due to lack of data
df1 = df.drop(columns = ['host_last_meal', 'host_body_temp', 'host_body_mass_index', 'host_occupation', 'host_pulse', \
                        'ihmc_medication_code', 'water_content', 'tot_nitro', 'abs_air_humidity', 'nitro',
                        'nitrite', 'methane', 'biomass']
)

# %%
df1.to_csv('11_ecoli_genome_data_featureless_cols_out.csv', index=False)
del df1
