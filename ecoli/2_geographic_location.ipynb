# %%
#Filters out the non-US states, and edits geo_loc_name into 'state' column to have only US state names, 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('12_ecoli_genome_data_more_filtering.csv', dtype=str)

# %%
keep_list_us = []
for i in df['geo_loc_name'].unique().tolist()[1:]:
    if 'USA' in i:
        keep_list_us.append(i)

# %%
#keep_list_us

# %%
#keep the rows with keep_list_us in df['geo_loc_name]
df_us = df[df['geo_loc_name'].isin(keep_list_us)]

# %%
#drop columns with all NaN
df_us = df_us.dropna(axis=1, how='all').reset_index(drop=True)

# %%
#df_us where Geo_location is not NaN
#df_us[df_us['Geo_location'].notnull()]

# %%
#df_us.info()

# %%
df_us['state'] = df_us['geo_loc_name']

# %%
df_us['state'] = df_us['state'].replace('USA:Boston', 'USA:MA')
df_us['state'] = df_us['state'].replace('USA: Boston', 'USA:MA')
df_us['state'] = df_us['state'].replace('USA: District of Columbia', 'USA:VA')
#if the entry string contains "California", replace the whole string with "USA:CA"
df_us['state'] = df_us['state'].replace('.*California.*', 'USA:CA', regex=True)
df_us['state'] = df_us['state'].replace('US: CA', 'USA:CA')
df_us['state'] = df_us['state'].replace('USA: Minnesota, Buffalo River Watershed', 'USA:MN')
df_us['state'] = df_us['state'].replace('USA: WA', 'USA:WA')
df_us['state'] = df_us['state'].replace('USA: Pittsburgh, Pennsylvania', 'USA:PA')
df_us['state'] = df_us['state'].replace('USA: Houston', 'USA:TX')
df_us['state'] = df_us['state'].replace('USA:Nebraska', 'USA:NE')
df_us['state'] = df_us['state'].replace('USA: NC', 'USA:NC')
df_us['state'] = df_us['state'].replace('USA: NY', 'USA:NY')
df_us['state'] = df_us['state'].replace('USA: Rochester, NY', 'USA:NY')
#use the value counts printout in the cell above to do similar replacements for the rest of the states
df_us['state'] = df_us['state'].replace('USA: IL', 'USA:IL')
df_us['state'] = df_us['state'].replace('USA: Pennsylvania', 'USA:PA')
df_us['state'] = df_us['state'].replace('USA: IN', 'USA:IN')
df_us['state'] = df_us['state'].replace('USA: Maywood, IL', 'USA:IN')
df_us['state'] = df_us['state'].replace('USA: GA', 'USA:GA')
df_us['state'] = df_us['state'].replace('USA: Nashville', 'USA:TN')
df_us['state'] = df_us['state'].replace('USA: KY', 'USA:KY')
df_us['state'] = df_us['state'].replace('USA: NE', 'USA:NE')
df_us['state'] = df_us['state'].replace('USA: MO', 'USA:MO')
df_us['state'] = df_us['state'].replace('USA: MI', 'USA:MI')
df_us['state'] = df_us['state'].replace('USA: NM', 'USA:NM')
df_us['state'] = df_us['state'].replace('USA: OH', 'USA:OH')
df_us['state'] = df_us['state'].replace('USA: OK', 'USA:OK')
df_us['state'] = df_us['state'].replace('USA: OR', 'USA:OR')
df_us['state'] = df_us['state'].replace('USA: PA', 'USA:PA')
df_us['state'] = df_us['state'].replace('USA: SC', 'USA:SC')
df_us['state'] = df_us['state'].replace('USA: TN', 'USA:TN')
df_us['state'] = df_us['state'].replace('USA: TX', 'USA:TX')
df_us['state'] = df_us['state'].replace('USA: VA', 'USA:VA')
df_us['state'] = df_us['state'].replace('USA: WA', 'USA:WA')
df_us['state'] = df_us['state'].replace('USA: WI', 'USA:WI')
df_us['state'] = df_us['state'].replace('USA: WV', 'USA:WV')
df_us['state'] = df_us['state'].replace('USA: WY', 'USA:WY')
df_us['state'] = df_us['state'].replace('USA: VT', 'USA:VT')
df_us['state'] = df_us['state'].replace('USA: UT', 'USA:UT')
df_us['state'] = df_us['state'].replace('USA: RI', 'USA:RI')
df_us['state'] = df_us['state'].replace('USA: NH', 'USA:NH')
df_us['state'] = df_us['state'].replace('USA: NV', 'USA:NV')
df_us['state'] = df_us['state'].replace('USA: NJ', 'USA:NJ')
df_us['state'] = df_us['state'].replace('USA: ND', 'USA:ND')
df_us['state'] = df_us['state'].replace('USA: MT', 'USA:MT')
df_us['state'] = df_us['state'].replace('USA: MS', 'USA:MS')
df_us['state'] = df_us['state'].replace('USA: MD', 'USA:MD')
df_us['state'] = df_us['state'].replace('USA: ME', 'USA:ME')
df_us['state'] = df_us['state'].replace('USA: LA', 'USA:LA')
df_us['state'] = df_us['state'].replace('USA: KS', 'USA:KS')
df_us['state'] = df_us['state'].replace('USA: IA', 'USA:IA')
df_us['state'] = df_us['state'].replace('USA: ID', 'USA:ID')
df_us['state'] = df_us['state'].replace('USA: HI', 'USA:HI')
df_us['state'] = df_us['state'].replace('USA: DE', 'USA:DE')
df_us['state'] = df_us['state'].replace('USA: CT', 'USA:CT')
df_us['state'] = df_us['state'].replace('USA: CO', 'USA:CO')
df_us['state'] = df_us['state'].replace('USA: AZ', 'USA:AZ')
df_us['state'] = df_us['state'].replace('USA: AK', 'USA:AK')
df_us['state'] = df_us['state'].replace('USA: AL', 'USA:AL')
df_us['state'] = df_us['state'].replace('USA: AR', 'USA:AR')
df_us['state'] = df_us['state'].replace('USA: FL', 'USA:FL')
df_us['state'] = df_us['state'].replace('USA: GA', 'USA:GA')
df_us['state'] = df_us['state'].replace('USA: IL', 'USA:IL')
df_us['state'] = df_us['state'].replace('USA: IN', 'USA:IN')
#if the entry string contains " IA", replace the whole string with "USA:IA"
df_us['state'] = df_us['state'].replace('.* IA', 'USA:IA', regex=True)
df_us['state'] = df_us['state'].replace('USA: Southeast Michigan', 'USA:MI')
df_us['state'] = df_us['state'].replace('USA: San Francisco', 'USA:CA')
df_us['state'] = df_us['state'].replace('USA:Kansas', 'USA:KS')
df_us['state'] = df_us['state'].replace('USA: Ohio', 'USA:OH')
df_us['state'] = df_us['state'].replace('.* CA', 'USA:CA', regex=True)
#if the entry string contains " Alaska", replace the whole string with "USA:AK"
df_us['state'] = df_us['state'].replace('.* Alaska', 'USA:AK', regex=True)
df_us['state'] = df_us['state'].replace('.* TN', 'USA:TN', regex=True)
df_us['state'] = df_us['state'].replace('.* MO', 'USA:MO', regex=True)
df_us['state'] = df_us['state'].replace('.* TX', 'USA:TX', regex=True)
df_us['state'] = df_us['state'].replace('.* FL', 'USA:FL', regex=True)
df_us['state'] = df_us['state'].replace('.* WA', 'USA:WA', regex=True)
df_us['state'] = df_us['state'].replace('.* NY', 'USA:NY', regex=True)
df_us['state'] = df_us['state'].replace('.* MN', 'USA:MN', regex=True)
df_us['state'] = df_us['state'].replace('.* IN', 'USA:IN', regex=True)
df_us['state'] = df_us['state'].replace('.* SD', 'USA:SD', regex=True)
df_us['state'] = df_us['state'].replace('.* GA', 'USA:GA', regex=True)
df_us['state'] = df_us['state'].replace('.* VA', 'USA:VA', regex=True)
df_us['state'] = df_us['state'].replace('.* NC', 'USA:NC', regex=True)
df_us['state'] = df_us['state'].replace('.* SC', 'USA:SC', regex=True)
df_us['state'] = df_us['state'].replace('USA: St. Louis Clyde watershed of Lake Superior', 'USA:MN')
df_us['state'] = df_us['state'].replace('USA:ARIZONA', 'USA:AZ')
df_us['state'] = df_us['state'].replace('USA: Seattle', 'USA:WA')
df_us['state'] = df_us['state'].replace('USA: St. Louis', 'USA:MO')
df_us['state'] = df_us['state'].replace('USA: Minnesota', 'USA:MN')
df_us['state'] = df_us['state'].replace('USA: Maine', 'USA:ME')
df_us['state'] = df_us['state'].replace('USA: Wyoming', 'USA:WY')
df_us['state'] = df_us['state'].replace('USA: Nebraska', 'USA:NE')
df_us['state'] = df_us['state'].replace('USA: Philadelphia', 'USA:PA')
df_us['state'] = df_us['state'].replace('USA:Washington DC', 'USA:VA')
df_us['state'] = df_us['state'].replace('USA:DC', 'USA:VA')
df_us['state'] = df_us['state'].replace('.*Illinois.*', 'USA:IL', regex=True)
df_us['state'] = df_us['state'].replace('.* IL.*', 'USA:IL', regex=True)
df_us['state'] = df_us['state'].replace('.*Maryland.*', 'USA:IL', regex=True)
df_us['state'] = df_us['state'].replace('.*Chicago.*', 'USA:IL', regex=True)
df_us['state'] = df_us['state'].replace('USA:Utah', 'USA:UT')
for i in us_states:
    df_us['state'] = df_us['state'].replace('.*'+i+'.*', 'USA:'+us_states_abbr[us_states.index(i)], regex=True)
    df_us['state'] = df_us['state'].replace('.*'+us_states_abbr[us_states.index(i)], 'USA:'+us_states_abbr[us_states.index(i)], regex=True)
df_us['state'] = df_us['state'].replace('USA: Pittsburgh, Magee-Womens Hospital of UPMC', 'USA:PA')
df_us['state'] = df_us['state'].replace('.*Seattle.*', 'USA:WA', regex=True)
df_us['state'] = df_us['state'].replace('USA: St Louis', 'USA:MO', regex=True)
df_us['state'] = df_us['state'].replace('USA: Minneapolis', 'USA:MN', regex=True)
df_us['state'] = df_us['state'].replace('USA:San Francisco', 'USA:CA', regex=True)
df_us['state'] = df_us['state'].replace('USA: UC Davis Medical Center', 'USA:CA', regex=True)
df_us['state'] = df_us['state'].replace('USA: UC Davis Medical Center, Davis, Ca', 'USA:CA', regex=True)
df_us['state'] = df_us['state'].replace('USA: DC', 'USA:VA', regex=True)
df_us['state'] = df_us['state'].replace('USA:MIT', 'USA:MA', regex=True)
df_us['state'] = df_us['state'].replace('USA: Baltimore', 'USA:MD', regex=True)
df_us['state'] = df_us['state'].replace('USA: Houston', 'USA:TX', regex=True)

list_of_states = ['USA:AL','USA:AK','USA:AZ','USA:AR','USA:CA','USA:CO','USA:CT','USA:DE','USA:FL','USA:GA','USA:HI','USA:ID','USA:IL','USA:IN','USA:IA','USA:KS','USA:KY','USA:LA','USA:ME','USA:MD','USA:MA','USA:MI','USA:MN','USA:MS','USA:MO','USA:MT','USA:NE','USA:NV','USA:NH','USA:NJ','USA:NM','USA:NY','USA:NC','USA:ND','USA:OH','USA:OK','USA:OR','USA:PA','USA:RI','USA:SC','USA:SD','USA:TN','USA:TX','USA:UT','USA:VT','USA:VA','USA:WA','USA:WV','USA:WI','USA:WY']



df_us['state'].value_counts()
# Out:
# state
# USA                                                61558
# USA:CA                                             11507
# USA:PA                                              4719
# USA:TX                                              3179
# USA:VA                                              2812
# USA:WA                                              2435
# USA:IA                                              2242
# USA:NC                                              2167
# USA:MN                                              2116
# USA:NY                                              1804
# USA:MA                                              1702
# USA:OH                                              1511
# USA:NE                                              1507
# USA:KS                                              1489
# USA:TN                                              1450
# USA:MI                                              1387
# ...

# %%
for i in range(len(df_us)):
    if df_us.loc[i, 'state'] not in list_of_states:
        df_us.loc[i, 'state'] = 'uncategorized'

# %%
#make a bar plot of the counts of df['states'] with each member of list_of_states
#fig, ax = plt.subplots()
#df_us['state'].loc[df_us['state'].isin(list_of_states)].value_counts().plot(kind='bar', ax=ax)
#ax.set_xticks(range(len(list_of_states)))
#ax.set_xticklabels(df_us['state'].loc[df_us['state'].isin(list_of_states)].value_counts()[0], rotation=90)
#plt.show()

# %%
#rows of df_us where 'state' is USA and 'purpose_of_sampling' is not NaN
#df_us[(df_us['state'] == 'USA') & (df_us['purpose_of_sampling'].notnull())][0:10]

# %%
df_us.to_csv('13_us_states.csv', index=False)

# %%
del [df, df_us]
