# %%
#Takes the us_states data, and catagorizes the isolation_source by River, other_environment, human, or animal.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('13_us_states.csv', dtype=str)

# %%
df['new_isolation_source'] = df['isolation_source']
df['new_isolation_source'] = df['new_isolation_source'].replace('Missing', np.nan).replace('MISSING', np.nan).replace('missing', np.nan)
df['new_isolation_source'] = df['new_isolation_source'].replace('.* Not .*',np.nan, regex=True).replace('.*Not .*',np.nan, regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*Canis lupus familiaris.*','Animal', regex=True).replace('.*Canis lupus familaris.*','Animal', regex=True).replace('.*Canis lupus.*','Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*cecum of Ec-FL1-1X 2-week old.*', 'TOO_LONG', regex=True).replace('.*cecum of Ec-RL2-1X 2-week old.*', 'TOO_LONG', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*human.*', 'Human', regex=True).replace('.*Human.*', 'Human', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*cow.*', 'Animal', regex=True).replace('produce near bovine', 'Vegetation').replace('.*bovine.*', 'Animal', regex=True).replace('.*Bovine.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('dairy calf feces', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('.*poultry.*', 'Animal', regex=True).replace('.*Poultry.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('ground turkey', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('Ground Beef', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('feces (Bos taurus)', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('animal-swine-market swine', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('.*beef.*', 'Animal', regex=True).replace('.*Beef.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('wastewater', 'Water').replace('water', 'Water')
df['new_isolation_source'] = df['new_isolation_source'].replace('.*chicken.*', 'Animal', regex=True).replace('.*Chicken.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*turkey.*', 'Animal', regex=True).replace('.*Turkey.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*cattle.*', 'Animal', regex=True).replace('.*Cattle.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*Pork.*', 'Animal', regex=True).replace('.*pork.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*pig.*', 'Animal', regex=True).replace('.*Pig.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*animal.*', 'Animal', regex=True).replace('.*Animal.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('.*Patient.*', 'Human', regex=True).replace('.*patient.*', 'Human', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('urine', 'Unknown').replace('stool', 'Unknown').replace('feces', 'Unknown')
df['new_isolation_source'] = df['new_isolation_source'].replace('soil', 'Environment').replace('sediment', 'Environment').replace('dirt', 'Environment').replace('environment', 'Environment')
df['new_isolation_source'] = df['new_isolation_source'].replace('water', 'Water').replace('wastewater', 'Water').replace('sewage', 'Environment')
df['new_isolation_source'] = df['new_isolation_source'].replace('Feces, Gull (Larus spp.)', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('.*manure.*', 'Animal', regex=True).replace('.*Manure.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('Feral swine feces', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('.*Sus domesticus.*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('feces elk', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('swine feces', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('spinach', 'Vegetation')
df['new_isolation_source'] = df['new_isolation_source'].replace('Calf fecal composite', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('stool (Odocoileus hemionus)', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('oyster', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('romaine lettuce', 'Vegetation')
df['new_isolation_source'] = df['new_isolation_source'].replace('stool .*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('farm', 'Envirnoment')
df['new_isolation_source'] = df['new_isolation_source'].replace('fecal .*', 'Animal', regex=True)
df['new_isolation_source'] = df['new_isolation_source'].replace('pond water', 'Water')
df['new_isolation_source'] = df['new_isolation_source'].replace('rectal swab from healthy college student', 'Human')
df['new_isolation_source'] = df['new_isolation_source'].replace('hide', 'Animal')
df['new_isolation_source'] = df['new_isolation_source'].replace('surface water', 'Water')

list_of_sources = ['Animal', 'Environment', 'Human', 'Vegetation', 'Water']
for i in range(len(df)):
    if df.loc[i,'new_isolation_source'] not in list_of_sources:
        df.loc[i,'new_isolation_source'] = 'Uncatagorized'



df['new_isolation_source'].value_counts()
# Out:
# new_isolation_source
# Uncatagorized    86262
# Animal           31364
# Water             2570
# Human              877
# Environment        810
# Vegetation         287
# Name: count, dtype: int64

# %%
df.to_csv('14_isolation_source.csv', index=False)

# %%
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del df
#
# NameError: name 'df' is not defined
