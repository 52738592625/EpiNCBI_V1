# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
# Load the data with dtype string to keep things consistant for now
df = pd.read_csv('11_us_states.csv', dtype=str)

# %%
n=1
for i in df.columns.tolist():
    print('column index:', n, 'out of', len(df.columns))
    n+=1
    print(df[i].value_counts().head(10))
    print(len(df) - df[i].isna().sum())
    print('-'*50)
# Out:
# column index: 1 out of 156
# sample
# GCA_000173695.1    1
# GCA_020612955.1    1
# GCA_020613215.1    1
# GCA_020613175.1    1
# GCA_020613155.1    1
# GCA_020613135.1    1
# GCA_020613115.1    1
# GCA_020613095.1    1
# GCA_020613075.1    1
# GCA_020613035.1    1
# Name: count, dtype: int64
# 386148
# --------------------------------------------------
# column index: 2 out of 156
# AntigenForm
# 4,12:i:1,2        235
# Poly A             14
# I 4,12:i:-         12
# I 4,5,12:i-        10
# P 38:k:1,6          9
# 9,12:Nonmotile      8
# I 4,5,12:b:-        8
# Poly B              8
# I 4,[5],12:i:-      8
# 4,5,12:r:-          6
# Name: count, dtype: int64
# 412
# --------------------------------------------------
# column index: 3 out of 156
# Antigenic formulae
# 8:e,h:1,2        90
# 3,10:e,h:1,6     74
# 7:e,h:e,n,z15    60
# 7:r:1,5          42
# 4:i:1,2          38
# 9:l,z28:1,5      24
# 11:r:e,n,x       23
# 3,10:l,v:1,7     12
# 7:g,m,s:-        12
# 7:k:1,5           8
# Name: count, dtype: int64
# 508
# --------------------------------------------------
# column index: 4 out of 156
# AssemblyVersion
# CLC Genomics Workbench v. 6.0.2    985
# Name: count, dtype: int64
# 985
# --------------------------------------------------
# column index: 5 out of 156
# Assembly_method
# Unicycler    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 6 out of 156
# Assembly_method_version
# v0.4.8    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 7 out of 156
# BioSample
# SAMN28450104    1
# SAMN42888496    1
# SAMN42888490    1
# SAMN42888492    1
# SAMN42888515    1
# SAMN42888543    1
# SAMN42888489    1
# SAMN42888511    1
# SAMN42888449    1
# SAMN42888517    1
# Name: count, dtype: int64
# 199
# --------------------------------------------------
# column index: 8 out of 156
# CFSAN number
# CFSAN019481    2
# CFSAN019483    2
# CFSAN019484    2
# CFSAN019485    2
# CFSAN019486    2
# CFSAN019487    2
# CFSAN019490    2
# CFSAN019491    2
# CFSAN019492    2
# CFSAN019493    2
# Name: count, dtype: int64
# 28
# --------------------------------------------------
# column index: 9 out of 156
# Deidentified Sample Names
# ClinicalA2    2
# ClinicalC1    2
# ClinicalC2    2
# ClinicalB3    2
# ClinicalB1    2
# ClinicalB2    2
# ClinicalA1    2
# ClinicalB4    2
# Name: count, dtype: int64
# 16
# --------------------------------------------------
# column index: 10 out of 156
# ENA first public
# 2011-02-14    5
# 2013-07-22    3
# 2022-05-03    2
# 2013-07-08    1
# Name: count, dtype: int64
# 11
# --------------------------------------------------
# column index: 11 out of 156
# ENA last update
# 2015-07-27    5
# 2016-07-22    4
# 2022-05-03    2
# Name: count, dtype: int64
# 11
# --------------------------------------------------
# column index: 12 out of 156
# ENA-CHECKLIST
# ERC000011    77
# ERC000028     2
# Name: count, dtype: int64
# 79
# --------------------------------------------------
# column index: 13 out of 156
# ENA-FIRST-PUBLIC
# 2013-07-08T10:06:55Z    22
# 2013-07-22T12:06:45Z    14
# 2013-12-19T12:09:22Z     6
# 2020-08-02T16:00:22Z     3
# 2019-08-15T15:59:15Z     3
# 2013-12-19T12:09:21Z     2
# 2015-03-03T09:45:01Z     2
# 2016-09-01T13:35:25Z     2
# 2016-12-06T09:50:16Z     2
# 2020-08-02T16:00:09Z     2
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 14 out of 156
# ENA-LAST-UPDATE
# 2018-03-09T10:09:21Z    13
# 2018-03-09T10:09:17Z    10
# 2018-03-09T10:09:48Z     8
# 2018-03-09T13:36:21Z     5
# 2020-08-02T16:00:22Z     3
# 2019-08-15T15:59:15Z     3
# 2018-03-09T10:32:27Z     2
# 2018-05-24T11:29:46Z     2
# 2018-06-13T13:28:44Z     2
# 2018-05-23T16:22:46Z     2
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 15 out of 156
# External Id
# SAMEA2272268     2
# SAMEA2272674     2
# SAMEA5851870     2
# SAMEA3222072     2
# SAMEA4028447     2
# SAMEA4557832     2
# SAMEA14288410    2
# SAMEA2272387     2
# SAMEA2272057     2
# SAMEA2053462     1
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 16 out of 156
# FDA CVM ID
# CVM 56-3991    2
# CVM 70-1605    2
# CVM 74-1357    2
# CVM 77-2980    2
# CVM 79-2359    2
# CVM 81-1435    2
# CVM 81-1706    2
# CVM 92-0392    2
# CVM 93-0639    2
# CVM 95-0621    2
# Name: count, dtype: int64
# 28
# --------------------------------------------------
# column index: 17 out of 156
# FDA_Lab_Id
# 1239863-C002-002    21
# 1268941              9
# 65201                5
# 65200                4
# 65198                3
# 1162780              3
# 1200081-S001-017     2
# 1221997              2
# 1177055              2
# 1182898-C001-001     2
# Name: count, dtype: int64
# 3257
# --------------------------------------------------
# column index: 18 out of 156
# FDA_lab_id
# 592602 2A       4
# 361154004       3
# 964069-2        3
# 169015          3
# 507440-20       2
# 571602          2
# 702776 56-26    2
# 702776 66-49    2
# 964097-1        2
# 703294-30       2
# Name: count, dtype: int64
# 7099
# --------------------------------------------------
# column index: 19 out of 156
# Full/Partial Assembly
# Full    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 20 out of 156
# Genus
# Salmonella    12665
# getGenus        141
# Name: count, dtype: int64
# 12806
# --------------------------------------------------
# column index: 21 out of 156
# HHS_region
# 5     5464
# 4     4301
# 3     3288
# 8     1870
# 1     1758
# 2     1242
# 10    1205
# 9     1119
# 6      702
# 7      354
# Name: count, dtype: int64
# 21303
# --------------------------------------------------
# column index: 22 out of 156
# INSDC center name
# SC                           45
# M. Achtman                   19
# EBI                           8
# Wellcome Sanger Institute     5
# WARWICK UNIVERSITY            3
# EMG                           2
# inrae nouzilly                2
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 23 out of 156
# INSDC first public
# 2013-07-08T10:06:55Z    22
# 2013-07-22T12:06:45Z    14
# 2013-12-19T12:09:22Z     6
# 2020-08-02T16:00:22Z     3
# 2019-08-15T15:59:15Z     3
# 2019-08-06T09:56:39Z     2
# 2015-03-03T09:45:01Z     2
# 2016-09-01T13:35:25Z     2
# 2016-12-06T09:50:16Z     2
# 2020-08-02T16:00:09Z     2
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 24 out of 156
# INSDC last update
# 2018-03-09T10:09:21Z    13
# 2018-03-09T10:09:17Z    10
# 2018-03-09T10:09:48Z     8
# 2018-03-09T13:36:21Z     5
# 2015-07-27T09:17:17Z     5
# 2020-08-02T16:00:22Z     3
# 2019-08-15T15:59:15Z     3
# 2018-03-09T10:32:27Z     2
# 2019-08-06T09:56:39Z     2
# 2018-05-24T11:29:46Z     2
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 25 out of 156
# INSDC status
# public    84
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 26 out of 156
# Institution
# Centers for Disease Control & Prevention      24
# Centers for Disease Control and Prevention     2
# Name: count, dtype: int64
# 26
# --------------------------------------------------
# column index: 27 out of 156
# Instrument model
# Illumina MiSeq    12
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 28 out of 156
# Isolate, name or label
# missing    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 29 out of 156
# LD50_no_of_organisms
# 128           2
# 190000        2
# >100000000    2
# 80            2
# 420000        2
# 21000         2
# 70000         2
# 23            2
# 210000        2
# 16            2
# Name: count, dtype: int64
# 20
# --------------------------------------------------
# column index: 30 out of 156
# LexMapr Version
# LexMapr-0.7.1    226
# Name: count, dtype: int64
# 226
# --------------------------------------------------
# column index: 31 out of 156
# Library name
# Nextera DNA Flex    12
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 32 out of 156
# NCBI Sample Category
# environmental/food/other    28
# Name: count, dtype: int64
# 28
# --------------------------------------------------
# column index: 33 out of 156
# Organisation name
# GenomeTrakr    289
# Name: count, dtype: int64
# 289
# --------------------------------------------------
# column index: 34 out of 156
# PFGE_PrimaryEnzyme_pattern
# JEGX01.0004    293
# JF6X01.0022    106
# JEGX01.0005     92
# JNXX01.0011     76
# JFXX01.0787     54
# JMPX01.0004     48
# JIXX01.0011     42
# JAGX01.0548     39
# TDRX01.0080     36
# JGPX01.0027     36
# Name: count, dtype: int64
# 5624
# --------------------------------------------------
# column index: 35 out of 156
# PFGE_SecondaryEnzyme_pattern
# JEGA26.0002     137
# Unconfirmed      52
# 0611ALJNX-1c     38
# JIXA26.0012      33
# JF6A26.0001      28
# JHXA26.0001      27
# JMPA26.0015      26
# JEGA26.0004      23
# TEEA26.0003      19
# JPXA26.0332      15
# Name: count, dtype: int64
# 843
# --------------------------------------------------
# column index: 36 out of 156
# Phagetype
# PT8      48
# PT13     30
# PT13a     6
# PT23      4
# PT35      2
# PT28      2
# PT21      2
# PT2       2
# PT14b     2
# Name: count, dtype: int64
# 98
# --------------------------------------------------
# column index: 37 out of 156
# Project
# LFFM    29
# Name: count, dtype: int64
# 29
# --------------------------------------------------
# column index: 38 out of 156
# ProjectAccession
# PRJNA186035    7419
# PRJNA280335     884
# PRJNA338674     578
# PRJNA284276     269
# PRJNA293224     245
# PRJNA271470     214
# PRJNA308180     211
# PRJNA316457     176
# PRJNA324570     128
# PRJNA292661     126
# Name: count, dtype: int64
# 11501
# --------------------------------------------------
# column index: 39 out of 156
# PublicAccession
# CFSAN070646    2
# CFSAN071932    2
# CFSAN071965    2
# CFSAN071937    2
# CFSAN071964    2
# CFSAN071947    2
# CFSAN071955    2
# CFSAN071949    2
# CFSAN071940    2
# CFSAN071936    2
# Name: count, dtype: int64
# 13010
# --------------------------------------------------
# column index: 40 out of 156
# SGI-4_genotype
# chromosome    6
# plasmid       4
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 41 out of 156
# SPUID namespace
# GenomeTrakr    289
# Name: count, dtype: int64
# 289
# --------------------------------------------------
# column index: 42 out of 156
# Sample_number
# 24    2
# 12    2
# 34    2
# 20    2
# 14    2
# 15    2
# 23    2
# 26    2
# 27    2
# 29    2
# Name: count, dtype: int64
# 74
# --------------------------------------------------
# column index: 43 out of 156
# SequencingTechnology
# Illumina MiSeq    985
# Name: count, dtype: int64
# 985
# --------------------------------------------------
# column index: 44 out of 156
# Species
# enterica      12637
# getSpecies      141
# bongori           1
# sp.               1
# Name: count, dtype: int64
# 12780
# --------------------------------------------------
# column index: 45 out of 156
# State
# NY    40
# MD    20
# Name: count, dtype: int64
# 60
# --------------------------------------------------
# column index: 46 out of 156
# Submitter Id
# GCA_000388655                                    2
# GCA_000388675                                    2
# MGYG-HGUT-02366                                  2
# NCTC6086-sc-2222880                              2
# bf78ed50-2be4-11e6-a63e-3c4a9275d6c8             2
# 0720fb20-1367-11e6-b3a6-3c4a9275d6c8             2
# AM04528                                          2
# GCA_000388695                                    2
# GCA_000388715                                    2
# 115_2012K_175-sc-2013-02-27T10:27:21Z-1500476    1
# Name: count, dtype: int64
# 84
# --------------------------------------------------
# column index: 47 out of 156
# Tax ID
# 149385     8
# 595        4
# 932733     2
# 399586     2
# 1192850    2
# 57741      2
# 486997     2
# 1192578    2
# 2793261    2
# 90370      1
# Name: count, dtype: int64
# 27
# --------------------------------------------------
# column index: 48 out of 156
# Toxin
# Stx2         13
# Stx1/Stx2     1
# Name: count, dtype: int64
# 14
# --------------------------------------------------
# column index: 49 out of 156
# VirulenceMarker
# invA    43
# Name: count, dtype: int64
# 43
# --------------------------------------------------
# column index: 50 out of 156
# alias
# USDA-ARS-USMARC-1921    2
# USDA-ARS-USMARC-1914    2
# USDA-ARS-USMARC-1915    2
# USDA-ARS-USMARC-1917    2
# USDA-ARS-USMARC-1918    2
# USDA-ARS-USMARC-1919    2
# USDA-ARS-USMARC-1916    2
# USDA-ARS-USMARC-1920    2
# Name: count, dtype: int64
# 16
# --------------------------------------------------
# column index: 51 out of 156
# alternate_ID
# USDA-ARS-USMARC-1934    2
# WLSH-25                 2
# MD-4                    2
# CVM-5                   2
# CVM-7                   2
# CVM-10                  2
# CVM-11                  2
# CVM-13                  2
# CVM-14                  2
# CVM-15                  2
# Name: count, dtype: int64
# 62
# --------------------------------------------------
# column index: 52 out of 156
# animal_env
# Not Provided                                    28
# veterinary facility or diagnostic laboratory     4
# private household [ENVO:01000418]                3
# zoological facility                              1
# Name: count, dtype: int64
# 36
# --------------------------------------------------
# column index: 53 out of 156
# annot_source
# DIYA    12
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 54 out of 156
# anonymized name
# 3012STDY6045993    2
# 3012STDY6435358    2
# 3012STDY6408898    2
# 1500466            1
# 1500462            1
# 1500480            1
# 1500495            1
# 1500494            1
# 1500482            1
# 1500497            1
# Name: count, dtype: int64
# 44
# --------------------------------------------------
# column index: 55 out of 156
# assembly
# Celera Assembler v. 7.0 consensus accuracy 99.9998 Quiver version 2    4
# Celera Assembler v. 7.0 consensus accuracy 99.9996 Quiver version 2    2
# Celera Assembler v. 7.0 Consensus accuracy 100 : Quiver version 1      2
# Celera Assembler v. 7.0 consensus accuracy 99.9998                     2
# Celera Assembler v. 8.1 consensus accuracy 99.9999                     2
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 56 out of 156
# attribute package
# environmental/food/other    124
# Name: count, dtype: int64
# 124
# --------------------------------------------------
# column index: 57 out of 156
# attribute_package
# environmental/food/other    34615
# clinical/host-associated     2029
# Name: count, dtype: int64
# 36644
# --------------------------------------------------
# column index: 58 out of 156
# bacteria_available_from
# brad.bearson@usda.gov    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 59 out of 156
# biomaterial_provider
# MOD1                                                                  92
# SAR Collection                                                        91
# Hummus outbreak collection                                            15
# Salmonella Genetic Stock Centre (SGSC) - University of Calgary        12
# USDA NWRC (Jeff Chandler)                                              4
# Minnesota Department of Health                                         2
# ABTNL                                                                  2
# Deutsche Sammlung von Mikroorganismen und Zellkulturen GmbH (DSMZ)     2
# Salmonella Reference Collection B                                      1
# Name: count, dtype: int64
# 221
# --------------------------------------------------
# column index: 60 out of 156
# bioproject_accession
# PRJNA186035    11
# Name: count, dtype: int64
# 11
# --------------------------------------------------
# column index: 61 out of 156
# broker name
# EnteroBase    22
# ENA            8
# EBI-EMG        2
# Name: count, dtype: int64
# 32
# --------------------------------------------------
# column index: 62 out of 156
# coll_site_geo_feat
# grocery store [ENVO:01000984]     12
# market [ENVO:01000987]             9
# Environmental Swab-Farm            7
# Environmental Swab-Manure belt     3
# Name: count, dtype: int64
# 31
# --------------------------------------------------
# column index: 63 out of 156
# collected_by
# CDC                                                                                                                    218962
# USDA-FSIS                                                                                                               52836
# missing                                                                                                                 33778
# Missing                                                                                                                 12177
# FDA                                                                                                                      8465
# FDA Contracted Laboratory                                                                                                8259
# United States Food and Drug Administration                                                                               7381
# Texas A&M University                                                                                                     3233
# United States Food and Drug Administration| Office of Regulatory Affairs| New York Human and Animal Food Laboratory      2868
# Minnesota Department of Health                                                                                           1828
# Name: count, dtype: int64
# 385619
# --------------------------------------------------
# column index: 64 out of 156
# collection_date
# 2023       26380
# missing    24663
# 2022       10281
# 2018        8461
# 2019        8394
# 2017        8042
# 2021        7849
# 2024        7724
# 2020        6699
# 2016        5831
# Name: count, dtype: int64
# 386108
# --------------------------------------------------
# column index: 65 out of 156
# contact_email
# ECRC@psu.edu    74
# Name: count, dtype: int64
# 74
# --------------------------------------------------
# column index: 66 out of 156
# contact_lab
# Dudley Lab    74
# Name: count, dtype: int64
# 74
# --------------------------------------------------
# column index: 67 out of 156
# cult_isol_date
# 2024-04-10    4
# 2024-08-05    3
# 2023-06-15    2
# 2024-05-08    2
# 2023-06-09    1
# 2024-01-24    1
# 06/24/2024    1
# Name: count, dtype: int64
# 14
# --------------------------------------------------
# column index: 68 out of 156
# culture_collection
# missing             1982
# Missing              613
# ATCC:13076             6
# ATCC:14028s            5
# SGSC:2485              4
# ATCC:7378              3
# SGSC:2217              3
# SGSC:2211              3
# SGSC:2190              3
# FDA:FDAARGOS_609       2
# Name: count, dtype: int64
# 2767
# --------------------------------------------------
# column index: 69 out of 156
# description
# cntn_cf_publicComments                                                                                                                                                   1130
# Mus_musculus_farm_isolate                                                                                                                                                  50
# R. Binet et al (2017) Construction of stable fluorescent laboratory control strains for several food safety relevant Enterobacteriaceae- Food Microbiology (accepted)       8
# host disease: Pneumonia of Calves, Enzootic                                                                                                                                 3
# GA Dept Agriculture                                                                                                                                                         3
# Not Applicable                                                                                                                                                              2
# septisemia                                                                                                                                                                  2
# FDA Field - SFFL (FSE); HAFE4                                                                                                                                               2
# host disease: diarrhea                                                                                                                                                      2
# host disease: Salmonella Infections, Animal                                                                                                                                 2
# Name: count, dtype: int64
# 1231
# --------------------------------------------------
# column index: 70 out of 156
# env_broad_scale
# agricultural ecosystem [ENVO:00000077]    66
# Not Applicable                            41
# aquatic ecosystem [ENVO:01001787]         30
# swine                                     10
# livestock-associated habitat               8
# human-associated habitat                   6
# Farm                                       4
# abattoir                                   4
# food source                                2
# terrestrial biome [ENVO:0000046]           2
# Name: count, dtype: int64
# 173
# --------------------------------------------------
# column index: 71 out of 156
# env_local_scale
# Not Applicable                              53
# livestock operation                         51
# freshwater [ENVO:00002011]                  30
# gastrointestinal                            10
# canal [ENVO:00000014]                       10
# livestock associated                         4
# mixed-use farm                               4
# Not available                                4
# Poultry Farm                                 4
# Swine Final Chilled Carcass Swab Isolate     2
# Name: count, dtype: int64
# 185
# --------------------------------------------------
# column index: 72 out of 156
# env_medium
# agricultural soil [ENVO:00002259]    43
# Not Applicable                       41
# canal [ENVO:00000014]                25
# waste water [ENVO:00002001]          12
# freshwater [ENVO:00002011]           10
# intestinal contents                  10
# animal litter                         8
# ground beef                           6
# river [ENVO:00000022]                 5
# animal manure                         4
# Name: count, dtype: int64
# 183
# --------------------------------------------------
# column index: 73 out of 156
# env_package
# missing    12
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 74 out of 156
# estimated_size
# 4667743      2
# 4,695,591    2
# 4,565,474    2
# 4856450      2
# 4731587      2
# 4769468      2
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 75 out of 156
# facility_type
# process/manufacturing    50
# Not Applicable           16
# refrigerated storage     10
# process/manufactoring     1
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 76 out of 156
# farm_water_source
# canal    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 77 out of 156
# fda_lab_id
# 487238              3
# 607307-2            3
# 648902 6-8          2
# 648904 3-6          2
# 653049 13-19        2
# 642044 8-1          2
# 561362 9-7          2
# 543463 42-20        2
# 648901 16-16        2
# 773536 C1 RV 1-1    2
# Name: count, dtype: int64
# 216
# --------------------------------------------------
# column index: 78 out of 156
# finishing_strategy
# Complete: 20X coverage: reads >= 6500        4
# Complete: 21x coverage: reads >= 11,500      2
# complete: 20X coverage: reads >= 10500       2
# complete: 22x coverage: reads >=8500         2
# complete: 22 X coverage: reads >=8,000 bp    2
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 79 out of 156
# food_origin
# USA:CA    5768
# USA:GA    4329
# USA:TX    3752
# USA:NC    3585
# USA:VA    2662
# USA:PA    2609
# USA:IN    2370
# USA:IL    2349
# USA:WA    2239
# USA:WI    2100
# Name: count, dtype: int64
# 75444
# --------------------------------------------------
# column index: 80 out of 156
# food_processing_method
# food (raw) [FOODON:03311126]       22
# food (ground) [FOODON:00002713]    14
# Missing                             1
# Name: count, dtype: int64
# 37
# --------------------------------------------------
# column index: 81 out of 156
# food_product_type
# food (unprocessed) [FOODON:03316056]        9
# processed food product [FOODON:03311737]    8
# Name: count, dtype: int64
# 17
# --------------------------------------------------
# column index: 82 out of 156
# food_source
# poultry or game bird [FOODON:03411563]    14
# bovine [FOODON:03414374]                  10
# swine [FOODON:03411136]                    1
# Name: count, dtype: int64
# 25
# --------------------------------------------------
# column index: 83 out of 156
# food_type_processed
# Missing                                 50
# meat food product [FOODON:00001006]     25
# dairy food product [FOODON:00001256]     2
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 84 out of 156
# genotype
# missing    412
# ST11         4
# MLST198      2
# Tm1          2
# ST638        2
# Tm11         1
# Tm15         1
# Tm14         1
# Tm23         1
# Tm7          1
# Name: count, dtype: int64
# 431
# --------------------------------------------------
# column index: 85 out of 156
# genus
# Salmonella    77
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 86 out of 156
# geo_loc_name
# USA       285912
# USA:CA      7059
# USA:TX      7021
# USA:GA      5475
# USA:NC      4717
# USA:MN      4483
# USA:WI      4028
# USA:NY      3982
# USA:PA      3266
# USA:OH      3088
# Name: count, dtype: int64
# 386148
# --------------------------------------------------
# column index: 87 out of 156
# geo_location
# USA: missing    44
# Name: count, dtype: int64
# 44
# --------------------------------------------------
# column index: 88 out of 156
# health_state
# Not available    12
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 89 out of 156
# host
# missing                  238056
# Missing                   31427
# Homo sapiens               7075
# Sus scrofa                 4668
# Bovine                     3803
# Gallus gallus              3101
# bovine                     3000
# Bos taurus                 2543
# Meleagris gallopavo         955
# Sus scrofa domesticus       611
# Name: count, dtype: int64
# 301180
# --------------------------------------------------
# column index: 90 out of 156
# host type
# Homo sapiens    19
# homo sapiens    15
# Name: count, dtype: int64
# 34
# --------------------------------------------------
# column index: 91 out of 156
# host(click_for_ncbi_taxo_brower)
# Sus scrofa domesticus    17
# Bos taurus                6
# Equus caballus            5
# Meleagris gallopavo       1
# Capra hircus              1
# Sistrurus miliarius       1
# Name: count, dtype: int64
# 31
# --------------------------------------------------
# column index: 92 out of 156
# host_age
# 0-4        3563
# 50-59      2527
# 20-29      2480
# 60-69      2250
# 30-39      2217
# 40-49      2147
# 10-19      1782
# 70-79      1558
# 5-9        1214
# Unknown     743
# Name: count, dtype: int64
# 21396
# --------------------------------------------------
# column index: 93 out of 156
# host_description
# Missing                                      18
# Not Applicable                               12
# Not applicable                                8
# renal transplant                              2
# Coyote                                        2
# Rheumatoid arthritis on immunosuppression     2
# Name: count, dtype: int64
# 44
# --------------------------------------------------
# column index: 94 out of 156
# host_disease
# missing                             246396
# Missing                              32864
# Salmonellosis                          960
# gastroenteritis                        862
# Salmonella infection                   253
# Salmonella infections or carrier       180
# Not Collected                          140
# Salmonella gastroenteritis             105
# not applicable                          89
# commensal                               74
# Name: count, dtype: int64
# 282885
# --------------------------------------------------
# column index: 95 out of 156
# host_disease_outcome
# Missing           548
# missing           380
# Not Applicable     12
# Unknown             6
# recovery            4
# Not applicable      2
# Recovery            2
# Name: count, dtype: int64
# 954
# --------------------------------------------------
# column index: 96 out of 156
# host_disease_stage
# Not Applicable    12
# Missing            6
# Unknown            6
# Not applicable     2
# Name: count, dtype: int64
# 26
# --------------------------------------------------
# column index: 97 out of 156
# host_health_state
# INFECTION              71
# not known              29
# ENVIRO                 15
# Not Applicable         12
# disease                 8
# UNKNOWN                 8
# Missing                 6
# Unknown                 6
# not collected           4
# Pyrexia, Bronchitis     2
# Name: count, dtype: int64
# 172
# --------------------------------------------------
# column index: 98 out of 156
# host_sex
# missing           44
# female            17
# male              13
# Not Applicable    12
# Unknown            6
# Missing            3
# Not applicable     2
# Name: count, dtype: int64
# 97
# --------------------------------------------------
# column index: 99 out of 156
# host_subject_id
# Salmonella-18      1
# PA16802PPY40088    1
# NY14853PPY40313    1
# PA16802PPY40031    1
# NY14853PPY40311    1
# NY14853PPY40307    1
# NY14853PPY40296    1
# NY14853PPY40290    1
# NY14853PPY40289    1
# NY14853PPY40286    1
# Name: count, dtype: int64
# 107
# --------------------------------------------------
# column index: 100 out of 156
# host_tissue_sampled
# Feces        25
# Lung         14
# Liver         9
# Intestine     8
# C12434        8
# feces         8
# liver         7
# lung          5
# intestine     4
# Kidney        2
# Name: count, dtype: int64
# 117
# --------------------------------------------------
# column index: 101 out of 156
# identification method
# Phenotypic identification           10
# Phenotypic and Molecular Methods     8
# Phenotypic characterization          4
# phenotypic identification            2
# culture                              2
# Name: count, dtype: int64
# 26
# --------------------------------------------------
# column index: 102 out of 156
# ifsac_category
# environmental-water                          6795
# environmental                                4031
# chicken                                      3861
# clinical/research| human                     3366
# turkey                                       2284
# veterinary clinical/research| cow            1860
# animal feed                                  1453
# veterinary clinical/research| pig            1358
# fish                                         1135
# environmental-factory/production facility    1101
# Name: count, dtype: int64
# 45344
# --------------------------------------------------
# column index: 103 out of 156
# intended_consumer
# not applicable             294
# human as food consumer      71
# not provided                26
# animal as food consumer      5
# Not Provided                 1
# Not Applicable               1
# Name: count, dtype: int64
# 398
# --------------------------------------------------
# column index: 104 out of 156
# investigation_type
# bacteria_archaea    12
# isolate              2
# Name: count, dtype: int64
# 14
# --------------------------------------------------
# column index: 105 out of 156
# isol_growth_condt
# Not available                         12
# not collected                         10
# Mackonkey Agar and grown in LB         4
# 37C in LB                              4
# LB broth @ 37C                         2
# Salmonella-Shigella Isolation Agar     2
# Name: count, dtype: int64
# 34
# --------------------------------------------------
# column index: 106 out of 156
# isolate
# missing                 230615
# Missing                   7811
# Culture                     96
# Meleagris gallopavo         43
# Sus domesticus              29
# Not Applicable              18
# Pogona                      16
# Equus ferus caballus        16
# Pathogen.cl                 16
# Bos taurus                  12
# Name: count, dtype: int64
# 244103
# --------------------------------------------------
# column index: 107 out of 156
# isolate_id
# Parental2        2
# 19CO01CB29-S1    1
# 20SC01GT01-S1    1
# 20SC01CB05-S1    1
# 20SC02PC01-S1    1
# 20SC01PC09-S1    1
# 20SC02CB09-S1    1
# 20SC02GT07-S1    1
# 20SC02PC06-S1    1
# 20SC03GT03-S1    1
# Name: count, dtype: int64
# 11
# --------------------------------------------------
# column index: 108 out of 156
# isolate_name_alias
# missing                          115302
# Meleagris gallapovo                  77
# Meleagris gallopavo                  35
# 5.3-3-P-W                             5
# S-A-Drip-3                            5
# S-A-Source-3                          5
# CFSAN001416                           4
# CFSAN000445                           4
# 12B06394-1                            4
# CDC 2011K-1137; OH 2011001596         4
# Name: count, dtype: int64
# 156183
# --------------------------------------------------
# column index: 109 out of 156
# isolate_number
# 188    1
# 601    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 599    1
# Name: count, dtype: int64
# 620
# --------------------------------------------------
# column index: 110 out of 156
# isolation_source
# missing                                                        225802
# stool                                                           19977
# Missing                                                         17840
# raw intact chicken                                              10245
# comminuted chicken                                               6024
# Product-Raw-Ground\, Comminuted or Otherwise Nonintact-Pork      5998
# comminuted beef                                                  4567
# ground turkey                                                    4289
# feces                                                            4064
# chicken breast                                                   3395
# Name: count, dtype: int64
# 385930
# --------------------------------------------------
# column index: 111 out of 156
# label
# CFSAN000179_01    2
# SQ0213            2
# CFSAN000211_01    2
# SQ0207            2
# SQ0149            2
# SQ0195            2
# CFSAN000191_01    2
# SQ0109            2
# SQ0106            2
# SQ0141            2
# Name: count, dtype: int64
# 211
# --------------------------------------------------
# column index: 112 out of 156
# lat_lon
# missing                     341850
# Missing                      34079
# not collected                 2371
# 34.57 N 101.48 W              1336
# 35.183090 N 102.076410 W       620
# 34.964162 N 101.802265 W       530
# Not Collected                  513
# Not collected                  510
# 30.61 N 96.35 W                508
# not provided                   339
# Name: count, dtype: int64
# 384429
# --------------------------------------------------
# column index: 113 out of 156
# long_read_coverage
# 262    2
# 96     2
# 442    2
# 198    2
# 247    2
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 114 out of 156
# narms_isolate_number
# 18NY01GT09    3
# N4541         2
# CVM 32997     1
# CVM N13662    1
# CVM N13205    1
# CVM N18433    1
# CVM N18448    1
# CVM N18401    1
# CVM N18449    1
# CVM N15815    1
# Name: count, dtype: int64
# 2784
# --------------------------------------------------
# column index: 115 out of 156
# note
# isolated from the 2006-2007 peanut butter outbreak    2
# Not Applicable                                        2
# Sophie                                                2
# LA50                                                  2
# Ward 3 stall 35                                       2
# Shivers                                               2
# Vel Kathy                                             2
# Docs Moon Pie                                         2
# Iso 1A                                                2
# tag 1771                                              2
# Name: count, dtype: int64
# 22
# --------------------------------------------------
# column index: 116 out of 156
# notes
# stock culture contains a mixed population, large colonies have SGI-4 as a chromosomal element, small colonies have SGI-4 as a free plasmid.      4
# stock culture from BBS1358 large colony variant                                                                                                  2
# stock culture from BBS1358 small colony variant                                                                                                  2
# stock culture contains a mixed population, some colonies have SGI-4 as a chromosomal element and other colonies have SGI-4 as a free plasmid.    2
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 117 out of 156
# num_replicons
# 1    28
# 2     4
# 0     2
# Name: count, dtype: int64
# 34
# --------------------------------------------------
# column index: 118 out of 156
# ontological term
# water:CHEBI_15377                                   2332
# turkey (ground or minced):FOODON_00002714           2005
# feces:UBERON_0001988                                1788
# environmental (swab or sampling):GENEPIO_0001732    1522
# chicken breast:FOODON_00002703                      1418
# chicken:FOODON_03411457                             1314
# missing:GENEPIO_0001618                              888
# feces:uberon_0001988                                 860
# bos taurus:NCBITAXON_9913, feces:UBERON_0001988      763
# river water:ENVO_01000599                            669
# Name: count, dtype: int64
# 40871
# --------------------------------------------------
# column index: 119 out of 156
# organism
# Salmonella enterica                                         50
# Salmonella enterica subsp. enterica serovar Typhimurium     24
# Salmonella enterica subsp. enterica serovar Newport          8
# Salmonella enterica subsp. enterica serovar Dublin           6
# Salmonella enterica subspecies enterica serovar Javiana      4
# Salmonella enterica subsp. enterica                          4
# Salmonella enterica subsp. enterica serovar Choleraesuis     3
# Salmonella enterica subspecies enterica serovar Pomona       2
# Salmonella enterica subsp. enterica serovar Enteritidis      2
# Salmonella enterica subsp. enterica serovar Mbandaka         2
# Name: count, dtype: int64
# 115
# --------------------------------------------------
# column index: 120 out of 156
# outbreak
# 1203NYJAP-1     78
# 0611ALJNX-1c    38
# 1305MLJMP-1     22
# 1208MLJBX-1     21
# 0903NVTEE-1     19
# 0904MLJIX-1     19
# 0704WIWWS-1c    17
# 1005NCJEG-1     12
# 0702MLJNX-1c    12
# 1306MLJF6-3     11
# Name: count, dtype: int64
# 492
# --------------------------------------------------
# column index: 121 out of 156
# package
# environmental/food/other    2228
# Name: count, dtype: int64
# 2228
# --------------------------------------------------
# column index: 122 out of 156
# parental_strain
# BSX120    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 123 out of 156
# parental_strain_background
# strain UK-1 with nalidixic acid resistance    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 124 out of 156
# passage_history
# environmental/food/other    15
# Missing                      6
# 2, plate then broth          5
# Not Applicable               2
# <10                          2
# Name: count, dtype: int64
# 30
# --------------------------------------------------
# column index: 125 out of 156
# pathogenicity
# animal     6
# human      4
# missing    2
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 126 out of 156
# pathotype
# CipR S. Kentucky MLST198    2
# Oslo                        2
# Saintpaul                   1
# Newport                     1
# Rissen                      1
# Agona                       1
# Panama                      1
# Houten                      1
# Weltevreden                 1
# Reading                     1
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 127 out of 156
# project_name
# PulseNet                               242642
# GenomeTrakr                             35005
# FSIS Product/Environmental Sampling     33276
# NARMS-FSIS Cecal                        10965
# missing                                  7448
# GenomeTrakr; LFFM-FY3                    1265
# GenomeTrakr; NARMS Retail Meat           1229
# GenomeTrakr; LFFM-FY2                     974
# Vet-LIRN                                  884
# GenomeTrakr; LFFM-FY4                     875
# Name: count, dtype: int64
# 335883
# --------------------------------------------------
# column index: 128 out of 156
# purpose_of_sampling
# Regulatory Sampling                        26957
# surveilliance [GENEPIO:0100004]            11159
# Exploratory Sampling                        6319
# Monitoring                                   232
# surveillance [GENEPIO:0100004]               175
# Monitoring (AMR project)                     132
# targeted surveillance [GENEPIO:0100006]       94
# research [GENEPIO:0100003]                    86
# not collected                                 45
# missing                                       44
# Name: count, dtype: int64
# 45510
# --------------------------------------------------
# column index: 129 out of 156
# ref_biomaterial
# PMID: 21345093    14
# Not available     12
# TBD               10
# Missing            6
# not available      4
# Not Applicable     2
# ATCC 43845         2
# not published      2
# Name: count, dtype: int64
# 52
# --------------------------------------------------
# column index: 130 out of 156
# reference_material
# Salmonella Reference Collection, SGSC:2485    4
# Type Strain ATCC:7378                         3
# inclusivity SAFE                              3
# Salmonella Reference Collection, SGSC:2217    3
# Salmonella Reference Collection, SGSC:2487    2
# Salmonella Reference Collection, SGSC:2238    2
# laboratory control strain                     2
# Salmonella Reference Collection, SGSC:3086    2
# Salmonella Reference Collection, SGSC:2244    2
# Salmonella Reference Collection, SGSC:2239    2
# Name: count, dtype: int64
# 97
# --------------------------------------------------
# column index: 131 out of 156
# samp_collect_device
# dead-end ultrafiltration    229
# drag swab [OBI:0002822]      26
# sampling cloth                2
# NPIP gauze                    1
# Name: count, dtype: int64
# 258
# --------------------------------------------------
# column index: 132 out of 156
# sample_name
# SAM_NAME                                10
# GCA_000388655                            2
# GCA_000388675                            2
# MGYG-HGUT-02366                          2
# NCTC6086-sc-2222880                      2
# bf78ed50-2be4-11e6-a63e-3c4a9275d6c8     2
# 0720fb20-1367-11e6-b3a6-3c4a9275d6c8     2
# AM04528                                  2
# GCA_000388695                            2
# GCA_000388715                            2
# Name: count, dtype: int64
# 95
# --------------------------------------------------
# column index: 133 out of 156
# sample_type
# pure culture         89
# missing              87
# whole organism       86
# Pure culture         86
# bacterial culture    81
# culture              25
# Genomic DNA          22
# Isolate              15
# cell culture         14
# tissue sample        12
# Name: count, dtype: int64
# 580
# --------------------------------------------------
# column index: 134 out of 156
# scientific_name
# Salmonella enterica subsp. enterica serovar Enteritidis           36
# Salmonella enterica                                               26
# Salmonella enterica subsp. enterica serovar Agona str. 26.F.98     2
# Salmonella enterica subsp. enterica serovar Agona str. 27.O.98     2
# Salmonella enterica subsp. enterica serovar Agona str. 28.O.08     2
# Salmonella enterica subsp. enterica serovar Agona str. 29.O.08     2
# Salmonella enterica subsp. enterica serovar Typhi                  2
# Salmonella enterica subsp. enterica serovar Infantis               2
# Salmonella enterica subsp. enterica serovar Havana                 2
# Salmonella sp. NCTC 7297                                           1
# Name: count, dtype: int64
# 77
# --------------------------------------------------
# column index: 135 out of 156
# seq_meth
# PacBio C3 P5                    4
# PacBio RS II C2 P4 and C3 P5    4
# PacBio C2 P4                    2
# PacBio RS II C3 P5              2
# Name: count, dtype: int64
# 12
# --------------------------------------------------
# column index: 136 out of 156
# sequenced_by
# United States Department of Agriculture|Food Safety and Inspection Service                  43785
# FL                                                                                          20961
# TX                                                                                          16846
# CA                                                                                          10928
# NC                                                                                           9158
# United States Food and Drug Administration| Center for Food Safety and Applied Nutrition     8985
# VA                                                                                           8904
# GA                                                                                           8761
# OH                                                                                           8587
# FDA Contracted Laboratory                                                                    8236
# Name: count, dtype: int64
# 335136
# --------------------------------------------------
# column index: 137 out of 156
# sequencing_technologies
# GridION, MiSeq    10
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 138 out of 156
# serotype
# I 4,[5],12:i:-      132
# Enteritidis         107
# ['Kentucky', '']    102
# ['Infantis', '']     84
# Kentucky             66
# Muenchen             58
# Weltevreden          56
# ['Reading', '']      50
# Infantis             50
# I 4,5,12:i:-         48
# Name: count, dtype: int64
# 1637
# --------------------------------------------------
# column index: 139 out of 156
# serovar
# missing                                                 116181
# Enteritidis                                              11318
# Typhimurium                                               6716
# Kentucky                                                  6584
# Infantis                                                  5848
# Salmonella enterica subsp. enterica serovar Infantis      5456
# Salmonella enterica subsp. enterica serovar Kentucky      4502
# Newport                                                   3941
# Montevideo                                                2992
# Heidelberg                                                2630
# Name: count, dtype: int64
# 227173
# --------------------------------------------------
# column index: 140 out of 156
# short_read_Coverage
# 112.5385    2
# 206.1024    2
# 112.591     2
# 271.734     2
# 116.9995    2
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 141 out of 156
# source_type
# human            251141
# food              21452
# environmental     15640
# animal            10628
# Not Provided        396
# missing             294
# unknown             251
# Unknown             112
# Animal feed          78
# other                23
# Name: count, dtype: int64
# 300048
# --------------------------------------------------
# column index: 142 out of 156
# spec_intended_cons
# pet animal as consumer     8
# animal as food consumer    4
# Not Applicable             1
# Name: count, dtype: int64
# 13
# --------------------------------------------------
# column index: 143 out of 156
# species
# enterica    136
# Name: count, dtype: int64
# 136
# --------------------------------------------------
# column index: 144 out of 156
# specimen_processing
# replicate    35
# Name: count, dtype: int64
# 35
# --------------------------------------------------
# column index: 145 out of 156
# specimen_processing_details
# multiple colony picks sequenced    35
# Name: count, dtype: int64
# 35
# --------------------------------------------------
# column index: 146 out of 156
# specimen_processing_id
# A1    3
# A8    2
# E     2
# C     2
# A7    2
# A4    2
# F     2
# A5    2
# B4    1
# B2    1
# Name: count, dtype: int64
# 30
# --------------------------------------------------
# column index: 147 out of 156
# strain
# missing       130
# Missing        15
# 3               7
# ATCC 13076      6
# 16              5
# 20              5
# 219             5
# 13              5
# 15              5
# 388             5
# Name: count, dtype: int64
# 383863
# --------------------------------------------------
# column index: 148 out of 156
# sub_species
# enterica          107117
# arizonae             293
# diarizonae           236
# houtenae             166
# salamae               77
# indica                 7
# Not Applicable         2
# VII                    1
# Name: count, dtype: int64
# 107899
# --------------------------------------------------
# column index: 149 out of 156
# subgroup
# enterica                        15086
# missing                            14
# enterica (subspecies I)             7
# C1                                  4
# arizonae                            4
# C2                                  2
# diarizonae                          1
# diarizonae (subspecies IIIb)        1
# Name: count, dtype: int64
# 15119
# --------------------------------------------------
# column index: 150 out of 156
# submitted_serotype
# Newport                        13
# Antigen formula: 30:b:e,n,x    12
# Infantis                        5
# Javiana                         5
# Cerro                           4
# 4, [5], 12:i:-                  4
# Rubislaw                        4
# Dublin                          4
# typhi                           4
# 4,[5],12:i:-                    3
# Name: count, dtype: int64
# 152
# --------------------------------------------------
# column index: 151 out of 156
# subsrc_note
# antigenic formula: 1,9,12:g,p:-                             6
# NIST Mixed Microbial RM strain                              4
# antigenic formula: O6,8;eh;1,2                              2
# avirulent strain lacking the main virulence determinants    2
# C2, O:6,8                                                   2
# antigenic formula: 9,46:Z38:-                               2
# monophasic                                                  2
# Serotype pending                                            2
# model plasmid                                               1
# Name: count, dtype: int64
# 23
# --------------------------------------------------
# column index: 152 out of 156
# subtype
# PT30        33
# enterica    21
# PT9c         1
# Name: count, dtype: int64
# 55
# --------------------------------------------------
# column index: 153 out of 156
# supplier_name
# NCTC6086_280115    2
# NCTC6703           2
# NCTC3072_060516    2
# OVG_041            1
# 104_AM25928_B      1
# 100_8_403          1
# 119_2012K_187      1
# 135_50_3079        1
# 133_48_0565        1
# 121_67             1
# Name: count, dtype: int64
# 45
# --------------------------------------------------
# column index: 154 out of 156
# type-material
# Missing                               6
# Not Applicable                        2
# type strain of Salmonella enterica    2
# Name: count, dtype: int64
# 10
# --------------------------------------------------
# column index: 155 out of 156
# type_strain
# T     33
# NT    10
# Name: count, dtype: int64
# 43
# --------------------------------------------------
# column index: 156 out of 156
# state
# Uncategorized     286787
# Texas              10394
# California          8112
# Georgia             5724
# North Carolina      5118
# Minnesota           4682
# New York            4439
# Wisconsin           4057
# Pennsylvania        3390
# Ohio                3119
# Name: count, dtype: int64
# 386148
# --------------------------------------------------

# %%
for col in df.columns:
    if len(df) - df[col].isna().sum() < 10:
        df = df.drop(col, axis=1)

# %%
col_interest = ['sample', 'geo_loc_name', 'attribute_package','collected_by', 'collection_date', 'state', 'host','host_age','host_disease','ifsac_category','isolate','isolation_source', 'lat_lon','project_name', 'purpose_of_sampling', 'source_type']
df = df[col_interest]

# %%
df.set_index('sample', inplace=True)

# %%
df.head(10)
# Out:
#                 attribute_package                                collected_by  \
# sample
# GCA_000173695.1               NaN                                     missing
# GCA_000188355.2               NaN                                         FDA
# GCA_000188375.2               NaN                                         FDA
# GCA_000188395.2               NaN                                         FDA
# GCA_000188555.2               NaN                                         FDA
# GCA_000188575.2               NaN                                         FDA
# GCA_000188955.5               NaN  United States Food and Drug Administration
# GCA_000189155.2               NaN                                         FDA
# GCA_000231465.2               NaN         New York State Department of Health
# GCA_000231485.2               NaN         New York State Department of Health
#
#                 collection_date          state          host host_age  \
# sample
# GCA_000173695.1         missing  Uncategorized           NaN      NaN
# GCA_000188355.2         missing   Rhode Island           NaN      NaN
# GCA_000188375.2         missing   Rhode Island           NaN      NaN
# GCA_000188395.2         missing   Rhode Island           NaN      NaN
# GCA_000188555.2     07-Apr-2010     California           NaN      NaN
# GCA_000188575.2     11-Nov-2009       Maryland  Homo sapiens      NaN
# GCA_000188955.5      2010-02-01  Uncategorized           NaN      NaN
# GCA_000189155.2     22-Jan-2010           Iowa           NaN      NaN
# GCA_000231465.2         2005-12  Uncategorized  Homo sapiens      NaN
# GCA_000231485.2         2006-11  Uncategorized  Homo sapiens      NaN
#
#                 host_disease                  ifsac_category  \
# sample
# GCA_000173695.1          NaN                             NaN
# GCA_000188355.2          NaN  other (flavoring or seasoning)
# GCA_000188375.2          NaN  other (flavoring or seasoning)
# GCA_000188395.2          NaN  other (flavoring or seasoning)
# GCA_000188555.2          NaN                             NaN
# GCA_000188575.2      missing        clinical/research, human
# GCA_000188955.5          NaN                   environmental
# GCA_000189155.2          NaN          multi-ingredient, meat
# GCA_000231465.2  unspecified                             NaN
# GCA_000231485.2  unspecified                             NaN
#
#                                      isolate           isolation_source  \
# sample
# GCA_000173695.1                          NaN                    missing
# GCA_000188355.2  FDA_2010_144_Black Pepper-6                 peppercorn
# GCA_000188375.2  FDA_2010_145_Black Pepper-5                 peppercorn
# GCA_000188395.2  FDA_2010_146_Black Pepper-7                 peppercorn
# GCA_000188555.2                          NaN  Hearts of Romaine-Organic
# GCA_000188575.2                          NaN                    missing
# GCA_000188955.5                          NaN         environmental swab
# GCA_000189155.2                          NaN                 lunch meat
# GCA_000231465.2                          NaN                unspecified
# GCA_000231485.2                          NaN                unspecified
#
#                              lat_lon project_name purpose_of_sampling  \
# sample
# GCA_000173695.1              missing          NaN                 NaN
# GCA_000188355.2              missing          NaN                 NaN
# GCA_000188375.2              missing          NaN                 NaN
# GCA_000188395.2              missing          NaN                 NaN
# GCA_000188555.2              missing          NaN                 NaN
# GCA_000188575.2              missing          NaN                 NaN
# GCA_000188955.5              missing  GenomeTrakr                 NaN
# GCA_000189155.2              missing          NaN                 NaN
# GCA_000231465.2  40.7143 N 73.8204 W          NaN                 NaN
# GCA_000231485.2  41.0572 N 73.7940 W          NaN                 NaN
#
#                    source_type
# sample
# GCA_000173695.1            NaN
# GCA_000188355.2           Food
# GCA_000188375.2           Food
# GCA_000188395.2           Food
# GCA_000188555.2            NaN
# GCA_000188575.2          Human
# GCA_000188955.5  environmental
# GCA_000189155.2           Food
# GCA_000231465.2            NaN
# GCA_000231485.2            NaN

# %%
df.to_csv('12_us_states_interesting_cols.csv')
