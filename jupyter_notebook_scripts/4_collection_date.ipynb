# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('14_isolation_source.csv', dtype=str)
df.head()
# Out:
#             genome   geo_loc_name attribute_package collected_by  \
# 0  GCA_000165655.2  USA: Virginia               NaN          NaN
# 1  GCA_000178315.1        USA: NE               NaN          NaN
# 2  GCA_000178695.1        USA: CA               NaN          NaN
# 3  GCA_000178715.1        USA: WI               NaN          NaN
# 4  GCA_000178735.1        USA: PA               NaN          NaN
#
#   collection_date          state          host        host_age  \
# 0            1979  Uncategorized  Homo sapiens  not determined
# 1            2006       Nebraska  Homo sapiens             NaN
# 2            2006     California  Homo sapiens             NaN
# 3            2006      Wisconsin  Homo sapiens             NaN
# 4            2006   Pennsylvania  Homo sapiens             NaN
#
#      host_disease ifsac_category isolate isolation_source         lat_lon  \
# 0  not determined            NaN     NaN              NaN  not determined
# ...

# %%
df['collection_date'].value_counts()
# Out:
# collection_date
# missing                 36456
# Missing                  5847
# 2023                     4115
# 2022                     3299
# 2019                     3120
# 2017                     2997
# 2018                     2943
# 2021                     2758
# 2010                     2266
# 2020                     1985
# 2016                     1875
# 2009                     1552
# 2014                     1342
# 2015                     1273
# 2024                     1000
# 2012                      994
# Unknown                   932
# 2011                      923
# 2013                      888
# 2008                      745
# 2000                      589
# 2006                      501
# 2007                      446
# 1999                      418
# 2001                      341
# 2003                      329
# 1982                      295
# 1985                      285
# 2002                      277
# 2005                      219
# ...

# %%
n = 0
df['collection_date'] = df['collection_date'].fillna('missing')
df['collection_year'] = df['collection_date']
years=[str(x) for x in list(range(1900,2025))]
df['collection_year'] = df['collection_year'].replace('Missing', 'missing').replace('Unknown', 'missing').replace('unknown', 'missing').replace('none','missing').replace('not applicable','missing').replace('not collected','missing').replace('not provided','missing').replace('Not collected','missing').replace('MISSING','missing').replace('not available', 'missing').replace('Not Collected','missing').replace('unspecified', 'missing').replace('Not available', 'missing')
#if the right four characters are in years, then keep them, otherwise replace with missing
for i in range(len(df)):
    n += 1
    r = df.loc[i,'collection_date'][-4:]
    l = df.loc[i,'collection_date'][0:4]
    if r in years:
       df.loc[i,'collection_year'] = r
    elif l in years:
        df.loc[i,'collection_year'] = l
    if n % 5000 == 0:
        print(n)


df['collection_year'].value_counts()
# Out:
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000
# 100000
# 105000
# 110000
# 115000
# 120000
# collection_year
# missing    44038
# 2019        7460
# 2021        7283
# 2023        6537
# 2020        6354
# 2018        6123
# 2022        5826
# 2015        4901
# 2017        4835
# 2016        4147
# 2014        3206
# 2010        2596
# 2013        2263
# 2009        1843
# 2012        1800
# 2024        1380
# 2011        1338
# 2006         978
# 2008         910
# 2007         827
# 2000         664
# 1985         516
# 2003         515
# 2005         470
# 1999         448
# 2001         381
# 1982         365
# 2002         302
# 1993         302
# 1998         283
# 1987         257
# 1988         253
# 2004         231
# 1990         221
# 1983         218
# 1997         197
# 1986         196
# 1995         195
# 1980         180
# 1979         162
# 1975         136
# ...

# %%
df.to_csv('15_states_dates.csv', index=False)
